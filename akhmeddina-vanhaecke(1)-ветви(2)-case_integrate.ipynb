# %% [markdown]
# # Квадратуры Лиувилля в декартовых координатах!
#
# # Случай Ахмеддины

# %%
# Переменные
var("p1,p2,q1,q2")
# Постоянные
var("a,b,f,g")
H=(p1^2+p2^2)/2 + (q1^2+q2^2)^2 + a*q1^2 + b*q2^2
F=(q1*p2-q2*p1)^2+(b-a)*(p1^2+2*q1^4+2*q1^2*q2^2+2*a*q1^2)
G=(q1*p2-q2*p1)^2+(a-b)*(p2^2+2*q2^4+2*q1^2*q2^2+2*b*q2^2)

# %% [markdown]
# Шаг 1. Ищем
# $$
# u= \frac{\partial p_1}{\partial q_2}
# $$
# Для этого ищем уравнение
# $$
# F_1(q_1, q_2, p_1)=0
# $$
#
# # Это уравнение используем для представления квадратуры.

# %%
k=PolynomialRing(QQ,[p2,p1,q2,q1,a,b,f,g], order='lex')
J=k*[F==f,G==g]
B=J.groebner_basis()

# %%
Eqp1=QQ[q1,q2,a,b,f,g][p1](B[-1])
Eqp1.lc()
# Out:
# q1^4*a^2 + 2*q1^2*q2^2*a^2 + q2^4*a^2 - 2*q1^4*a*b - 4*q1^2*q2^2*a*b - 2*q2^4*a*b + q1^4*b^2 + 2*q1^2*q2^2*b^2 + q2^4*b^2 + 2*q1^2*a^3 - 2*q2^2*a^3 - 6*q1^2*a^2*b + 6*q2^2*a^2*b + 6*q1^2*a*b^2 - 6*q2^2*a*b^2 - 2*q1^2*b^3 + 2*q2^2*b^3 + a^4 - 4*a^3*b + 6*a^2*b^2 - 4*a*b^3 + b^4

# %%
Eqp1.degree()
# Out:
# 4

# %%
Eqp1.monomials()
# Out:
# [p1^4, p1^2, 1]

# %%
A1=(Eqp1.coefficients())
aa1=A1[-1]
bb1=A1[-2]
cc1=A1[-3]

# %%
solve(SR(Eqp1), p1)[0].rhs()
# Out:
# -sqrt(-2*a*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^4*q2^4/(a*q1^4 - b*q1^4 
# ...

# %% [markdown]
# # Ветви

# %%
p1_1=-sqrt(-2*a*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 10*a*b*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 4*b^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 8*a*b*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*b^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*b*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^2*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 14*a^2*b*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 10*a*b^2*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a^4*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*a^3*b*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*b^2*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b^3*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - a^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*sqrt(4*a^4*b*q1^4*q2^2 - 16*a^3*b^2*q1^4*q2^2 + 24*a^2*b^3*q1^4*q2^2 - 16*a*b^4*q1^4*q2^2 + 4*b^5*q1^4*q2^2 + 4*a^5*q1^2*q2^4 - 16*a^4*b*q1^2*q2^4 + 24*a^3*b^2*q1^2*q2^4 - 16*a^2*b^3*q1^2*q2^4 + 4*a*b^4*q1^2*q2^4 + 4*a^5*b*q1^2*q2^2 - 16*a^4*b^2*q1^2*q2^2 + 24*a^3*b^3*q1^2*q2^2 - 16*a^2*b^4*q1^2*q2^2 + 4*a*b^5*q1^2*q2^2 - 2*a^2*g*q1^6 + 4*a*b*g*q1^6 - 2*b^2*g*q1^6 - 2*a^2*f*q1^4*q2^2 + 4*a*b*f*q1^4*q2^2 - 2*b^2*f*q1^4*q2^2 - 4*a^2*g*q1^4*q2^2 + 8*a*b*g*q1^4*q2^2 - 4*b^2*g*q1^4*q2^2 - 4*a^2*f*q1^2*q2^4 + 8*a*b*f*q1^2*q2^4 - 4*b^2*f*q1^2*q2^4 - 2*a^2*g*q1^2*q2^4 + 4*a*b*g*q1^2*q2^4 - 2*b^2*g*q1^2*q2^4 - 2*a^2*f*q2^6 + 4*a*b*f*q2^6 - 2*b^2*f*q2^6 - 4*a^3*g*q1^4 + 10*a^2*b*g*q1^4 - 8*a*b^2*g*q1^4 + 2*b^3*g*q1^4 - 2*a^3*f*q1^2*q2^2 + 4*a^2*b*f*q1^2*q2^2 - 2*a*b^2*f*q1^2*q2^2 - 2*a^2*b*g*q1^2*q2^2 + 4*a*b^2*g*q1^2*q2^2 - 2*b^3*g*q1^2*q2^2 + 2*a^3*f*q2^4 - 8*a^2*b*f*q2^4 + 10*a*b^2*f*q2^4 - 4*b^3*f*q2^4 - 2*a^4*g*q1^2 + 6*a^3*b*g*q1^2 - 6*a^2*b^2*g*q1^2 + 2*a*b^3*g*q1^2 + 2*a^3*b*f*q2^2 - 6*a^2*b^2*f*q2^2 + 6*a*b^3*f*q2^2 - 2*b^4*f*q2^2 - a*f*g*q1^2 + b*f*g*q1^2 + a*g^2*q1^2 - b*g^2*q1^2 - a*f^2*q2^2 + b*f^2*q2^2 + a*f*g*q2^2 - b*f*g*q2^2 - a^2*f*g + 2*a*b*f*g - b^2*f*g)*q1*q2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3))

# %%
p1_2=sqrt(-2*a*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 10*a*b*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 4*b^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 8*a*b*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*b^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*b*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^2*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 14*a^2*b*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 10*a*b^2*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a^4*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*a^3*b*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*b^2*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b^3*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - a^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*sqrt(4*a^4*b*q1^4*q2^2 - 16*a^3*b^2*q1^4*q2^2 + 24*a^2*b^3*q1^4*q2^2 - 16*a*b^4*q1^4*q2^2 + 4*b^5*q1^4*q2^2 + 4*a^5*q1^2*q2^4 - 16*a^4*b*q1^2*q2^4 + 24*a^3*b^2*q1^2*q2^4 - 16*a^2*b^3*q1^2*q2^4 + 4*a*b^4*q1^2*q2^4 + 4*a^5*b*q1^2*q2^2 - 16*a^4*b^2*q1^2*q2^2 + 24*a^3*b^3*q1^2*q2^2 - 16*a^2*b^4*q1^2*q2^2 + 4*a*b^5*q1^2*q2^2 - 2*a^2*g*q1^6 + 4*a*b*g*q1^6 - 2*b^2*g*q1^6 - 2*a^2*f*q1^4*q2^2 + 4*a*b*f*q1^4*q2^2 - 2*b^2*f*q1^4*q2^2 - 4*a^2*g*q1^4*q2^2 + 8*a*b*g*q1^4*q2^2 - 4*b^2*g*q1^4*q2^2 - 4*a^2*f*q1^2*q2^4 + 8*a*b*f*q1^2*q2^4 - 4*b^2*f*q1^2*q2^4 - 2*a^2*g*q1^2*q2^4 + 4*a*b*g*q1^2*q2^4 - 2*b^2*g*q1^2*q2^4 - 2*a^2*f*q2^6 + 4*a*b*f*q2^6 - 2*b^2*f*q2^6 - 4*a^3*g*q1^4 + 10*a^2*b*g*q1^4 - 8*a*b^2*g*q1^4 + 2*b^3*g*q1^4 - 2*a^3*f*q1^2*q2^2 + 4*a^2*b*f*q1^2*q2^2 - 2*a*b^2*f*q1^2*q2^2 - 2*a^2*b*g*q1^2*q2^2 + 4*a*b^2*g*q1^2*q2^2 - 2*b^3*g*q1^2*q2^2 + 2*a^3*f*q2^4 - 8*a^2*b*f*q2^4 + 10*a*b^2*f*q2^4 - 4*b^3*f*q2^4 - 2*a^4*g*q1^2 + 6*a^3*b*g*q1^2 - 6*a^2*b^2*g*q1^2 + 2*a*b^3*g*q1^2 + 2*a^3*b*f*q2^2 - 6*a^2*b^2*f*q2^2 + 6*a*b^3*f*q2^2 - 2*b^4*f*q2^2 - a*f*g*q1^2 + b*f*g*q1^2 + a*g^2*q1^2 - b*g^2*q1^2 - a*f^2*q2^2 + b*f^2*q2^2 + a*f*g*q2^2 - b*f*g*q2^2 - a^2*f*g + 2*a*b*f*g - b^2*f*g)*q1*q2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3))

# %%
p1_3=-sqrt(-2*a*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 10*a*b*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 4*b^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 8*a*b*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*b^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*b*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^2*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 14*a^2*b*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 10*a*b^2*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a^4*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*a^3*b*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*b^2*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b^3*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - a^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*sqrt(4*a^4*b*q1^4*q2^2 - 16*a^3*b^2*q1^4*q2^2 + 24*a^2*b^3*q1^4*q2^2 - 16*a*b^4*q1^4*q2^2 + 4*b^5*q1^4*q2^2 + 4*a^5*q1^2*q2^4 - 16*a^4*b*q1^2*q2^4 + 24*a^3*b^2*q1^2*q2^4 - 16*a^2*b^3*q1^2*q2^4 + 4*a*b^4*q1^2*q2^4 + 4*a^5*b*q1^2*q2^2 - 16*a^4*b^2*q1^2*q2^2 + 24*a^3*b^3*q1^2*q2^2 - 16*a^2*b^4*q1^2*q2^2 + 4*a*b^5*q1^2*q2^2 - 2*a^2*g*q1^6 + 4*a*b*g*q1^6 - 2*b^2*g*q1^6 - 2*a^2*f*q1^4*q2^2 + 4*a*b*f*q1^4*q2^2 - 2*b^2*f*q1^4*q2^2 - 4*a^2*g*q1^4*q2^2 + 8*a*b*g*q1^4*q2^2 - 4*b^2*g*q1^4*q2^2 - 4*a^2*f*q1^2*q2^4 + 8*a*b*f*q1^2*q2^4 - 4*b^2*f*q1^2*q2^4 - 2*a^2*g*q1^2*q2^4 + 4*a*b*g*q1^2*q2^4 - 2*b^2*g*q1^2*q2^4 - 2*a^2*f*q2^6 + 4*a*b*f*q2^6 - 2*b^2*f*q2^6 - 4*a^3*g*q1^4 + 10*a^2*b*g*q1^4 - 8*a*b^2*g*q1^4 + 2*b^3*g*q1^4 - 2*a^3*f*q1^2*q2^2 + 4*a^2*b*f*q1^2*q2^2 - 2*a*b^2*f*q1^2*q2^2 - 2*a^2*b*g*q1^2*q2^2 + 4*a*b^2*g*q1^2*q2^2 - 2*b^3*g*q1^2*q2^2 + 2*a^3*f*q2^4 - 8*a^2*b*f*q2^4 + 10*a*b^2*f*q2^4 - 4*b^3*f*q2^4 - 2*a^4*g*q1^2 + 6*a^3*b*g*q1^2 - 6*a^2*b^2*g*q1^2 + 2*a*b^3*g*q1^2 + 2*a^3*b*f*q2^2 - 6*a^2*b^2*f*q2^2 + 6*a*b^3*f*q2^2 - 2*b^4*f*q2^2 - a*f*g*q1^2 + b*f*g*q1^2 + a*g^2*q1^2 - b*g^2*q1^2 - a*f^2*q2^2 + b*f^2*q2^2 + a*f*g*q2^2 - b*f*g*q2^2 - a^2*f*g + 2*a*b*f*g - b^2*f*g)*q1*q2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3))

# %%
p1_4=sqrt(-2*a*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 10*a*b*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 4*b^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 8*a*b*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*b^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*b*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^2*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 14*a^2*b*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 10*a*b^2*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a^4*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*a^3*b*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*b^2*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b^3*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - a^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*sqrt(4*a^4*b*q1^4*q2^2 - 16*a^3*b^2*q1^4*q2^2 + 24*a^2*b^3*q1^4*q2^2 - 16*a*b^4*q1^4*q2^2 + 4*b^5*q1^4*q2^2 + 4*a^5*q1^2*q2^4 - 16*a^4*b*q1^2*q2^4 + 24*a^3*b^2*q1^2*q2^4 - 16*a^2*b^3*q1^2*q2^4 + 4*a*b^4*q1^2*q2^4 + 4*a^5*b*q1^2*q2^2 - 16*a^4*b^2*q1^2*q2^2 + 24*a^3*b^3*q1^2*q2^2 - 16*a^2*b^4*q1^2*q2^2 + 4*a*b^5*q1^2*q2^2 - 2*a^2*g*q1^6 + 4*a*b*g*q1^6 - 2*b^2*g*q1^6 - 2*a^2*f*q1^4*q2^2 + 4*a*b*f*q1^4*q2^2 - 2*b^2*f*q1^4*q2^2 - 4*a^2*g*q1^4*q2^2 + 8*a*b*g*q1^4*q2^2 - 4*b^2*g*q1^4*q2^2 - 4*a^2*f*q1^2*q2^4 + 8*a*b*f*q1^2*q2^4 - 4*b^2*f*q1^2*q2^4 - 2*a^2*g*q1^2*q2^4 + 4*a*b*g*q1^2*q2^4 - 2*b^2*g*q1^2*q2^4 - 2*a^2*f*q2^6 + 4*a*b*f*q2^6 - 2*b^2*f*q2^6 - 4*a^3*g*q1^4 + 10*a^2*b*g*q1^4 - 8*a*b^2*g*q1^4 + 2*b^3*g*q1^4 - 2*a^3*f*q1^2*q2^2 + 4*a^2*b*f*q1^2*q2^2 - 2*a*b^2*f*q1^2*q2^2 - 2*a^2*b*g*q1^2*q2^2 + 4*a*b^2*g*q1^2*q2^2 - 2*b^3*g*q1^2*q2^2 + 2*a^3*f*q2^4 - 8*a^2*b*f*q2^4 + 10*a*b^2*f*q2^4 - 4*b^3*f*q2^4 - 2*a^4*g*q1^2 + 6*a^3*b*g*q1^2 - 6*a^2*b^2*g*q1^2 + 2*a*b^3*g*q1^2 + 2*a^3*b*f*q2^2 - 6*a^2*b^2*f*q2^2 + 6*a*b^3*f*q2^2 - 2*b^4*f*q2^2 - a*f*g*q1^2 + b*f*g*q1^2 + a*g^2*q1^2 - b*g^2*q1^2 - a*f^2*q2^2 + b*f^2*q2^2 + a*f*g*q2^2 - b*f*g*q2^2 - a^2*f*g + 2*a*b*f*g - b^2*f*g)*q1*q2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3))

# %% [markdown]
# # Гамильтонов идеал Ахимеддины - 1

# %%
q2=0

# %%
p2=0

# %%
# Out:
# 2*(a - b)*q2^4 + p2^2*q1^2 - 2*p1*p2*q1*q2 + (a - b)*p2^2 + (2*(a - b)*q1^2 + 2*a*b - 2*b^2 + p1^2)*q2^2

# %%
q2
# Out:
# 0

# %%
G
# Out:
# (p2*q1 - p1*q2)^2 + (2*q1^2*q2^2 + 2*q2^4 + 2*b*q2^2 + p2^2)*(a - b)

# %%
G.subs(q2=0,p2=0)
# Out:
# 0

# %%
((((p1_1.subs(q2=0).subs(p2=0)).simplify_full().subs(g=0))).simplify_full()).simplify_full()
# Out:
# -sqrt(-(2*(a - b)*q1^4 + 2*(a^2 - a*b)*q1^2 + f)/(a - b))

# %%
(((p1_1.subs(q2=0).subs(p2=0)).simplify_full().subs(g=0))^2).simplify_full()
# Out:
# -(2*(a - b)*q1^4 + 2*(a^2 - a*b)*q1^2 + f)/(a - b)

# %%
(p1_2.subs(q2=0).subs(p2=0)).simplify_full().subs(g=0).simplify_full()
# Out:
# sqrt(-(2*(a - b)*q1^4 + 2*(a^2 - a*b)*q1^2 + f)/(a - b))

# %%
(p1_3.subs(q2=0).subs(p2=0)).simplify_full().subs(g=0).simplify_full()
# Out:
# -sqrt(-(2*(a - b)*q1^4 + 2*(a^2 - a*b)*q1^2 + f)/(a - b))

# %%
(p1_4.subs(q2=0).subs(p2=0)).simplify_full().subs(g=0).simplify_full()
# Out:
# sqrt(-(2*(a - b)*q1^4 + 2*(a^2 - a*b)*q1^2 + f)/(a - b))

# %%
F.subs(p2=0).subs(q2=0)
# Out:
# -(2*q1^4 + 2*a*q1^2 + p1^2)*(a - b)

# %% [markdown]
# # Квадратура в случае Ахмеддины
#
# $$\mathfrak{W}=\int\limits_{q_1(t=0)}^{q_1(t)} dq_1 \sqrt{\frac{f}{a-b}+2aq_1^2-2q_1^4}$$
#
# Закон движения получается так:
#
# $$\frac{\partial \mathfrak{W}}{\partial f} = Const =\frac{1}{2(a-b)}\int\limits_{q_1(t=0)}^{q_1(t)}  \frac{dq_1}{\sqrt{\frac{f}{a-b}+2aq_1^2-2q_1^4}}$$
#
# $$\Rightarrow q_1(t)$$

# %%
p1_2.variables()
# Out:
# (a, b, f, g, q1, q2)

# %% [markdown]
# $$q_1^2=t$$
#
# $$q_1=\sqrt{t}$$
#
# $$2q_1dq_1=dt$$
#
# $$dq_1=\frac{dt}{2q_1}=\frac{dt}{2\sqrt{t}}$$
#
# $$\int \sqrt{\frac{P_4+\sqrt{t P_3}}{tP_2}}dt$$

# %%
def branch_selection_1(q10,q20,p10,p20,a,b):
    f=((q1*p2-q2*p1)^2+(b-a)*(p1^2+2*q1^4+2*q1^2*q2^2+2*a*q1^2)).subs([q1==q10,q2==q20,p1==p10,p2==p20])
    g=((q1*p2-q2*p1)^2+(a-b)*(p2^2+2*q2^4+2*q1^2*q2^2+2*b*q2^2)).subs([q1==q10,q2==q20,p1==p10,p2==p20])
    p1_1=-sqrt(-2*a*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 10*a*b*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 4*b^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 8*a*b*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*b^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*b*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^2*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 14*a^2*b*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 10*a*b^2*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a^4*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*a^3*b*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*b^2*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b^3*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - a^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*sqrt(4*a^4*b*q1^4*q2^2 - 16*a^3*b^2*q1^4*q2^2 + 24*a^2*b^3*q1^4*q2^2 - 16*a*b^4*q1^4*q2^2 + 4*b^5*q1^4*q2^2 + 4*a^5*q1^2*q2^4 - 16*a^4*b*q1^2*q2^4 + 24*a^3*b^2*q1^2*q2^4 - 16*a^2*b^3*q1^2*q2^4 + 4*a*b^4*q1^2*q2^4 + 4*a^5*b*q1^2*q2^2 - 16*a^4*b^2*q1^2*q2^2 + 24*a^3*b^3*q1^2*q2^2 - 16*a^2*b^4*q1^2*q2^2 + 4*a*b^5*q1^2*q2^2 - 2*a^2*g*q1^6 + 4*a*b*g*q1^6 - 2*b^2*g*q1^6 - 2*a^2*f*q1^4*q2^2 + 4*a*b*f*q1^4*q2^2 - 2*b^2*f*q1^4*q2^2 - 4*a^2*g*q1^4*q2^2 + 8*a*b*g*q1^4*q2^2 - 4*b^2*g*q1^4*q2^2 - 4*a^2*f*q1^2*q2^4 + 8*a*b*f*q1^2*q2^4 - 4*b^2*f*q1^2*q2^4 - 2*a^2*g*q1^2*q2^4 + 4*a*b*g*q1^2*q2^4 - 2*b^2*g*q1^2*q2^4 - 2*a^2*f*q2^6 + 4*a*b*f*q2^6 - 2*b^2*f*q2^6 - 4*a^3*g*q1^4 + 10*a^2*b*g*q1^4 - 8*a*b^2*g*q1^4 + 2*b^3*g*q1^4 - 2*a^3*f*q1^2*q2^2 + 4*a^2*b*f*q1^2*q2^2 - 2*a*b^2*f*q1^2*q2^2 - 2*a^2*b*g*q1^2*q2^2 + 4*a*b^2*g*q1^2*q2^2 - 2*b^3*g*q1^2*q2^2 + 2*a^3*f*q2^4 - 8*a^2*b*f*q2^4 + 10*a*b^2*f*q2^4 - 4*b^3*f*q2^4 - 2*a^4*g*q1^2 + 6*a^3*b*g*q1^2 - 6*a^2*b^2*g*q1^2 + 2*a*b^3*g*q1^2 + 2*a^3*b*f*q2^2 - 6*a^2*b^2*f*q2^2 + 6*a*b^3*f*q2^2 - 2*b^4*f*q2^2 - a*f*g*q1^2 + b*f*g*q1^2 + a*g^2*q1^2 - b*g^2*q1^2 - a*f^2*q2^2 + b*f^2*q2^2 + a*f*g*q2^2 - b*f*g*q2^2 - a^2*f*g + 2*a*b*f*g - b^2*f*g)*q1*q2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3))
    p1_2=sqrt(-2*a*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 10*a*b*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 4*b^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 8*a*b*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*b^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*b*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^2*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 14*a^2*b*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 10*a*b^2*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a^4*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*a^3*b*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*b^2*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b^3*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - a^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*sqrt(4*a^4*b*q1^4*q2^2 - 16*a^3*b^2*q1^4*q2^2 + 24*a^2*b^3*q1^4*q2^2 - 16*a*b^4*q1^4*q2^2 + 4*b^5*q1^4*q2^2 + 4*a^5*q1^2*q2^4 - 16*a^4*b*q1^2*q2^4 + 24*a^3*b^2*q1^2*q2^4 - 16*a^2*b^3*q1^2*q2^4 + 4*a*b^4*q1^2*q2^4 + 4*a^5*b*q1^2*q2^2 - 16*a^4*b^2*q1^2*q2^2 + 24*a^3*b^3*q1^2*q2^2 - 16*a^2*b^4*q1^2*q2^2 + 4*a*b^5*q1^2*q2^2 - 2*a^2*g*q1^6 + 4*a*b*g*q1^6 - 2*b^2*g*q1^6 - 2*a^2*f*q1^4*q2^2 + 4*a*b*f*q1^4*q2^2 - 2*b^2*f*q1^4*q2^2 - 4*a^2*g*q1^4*q2^2 + 8*a*b*g*q1^4*q2^2 - 4*b^2*g*q1^4*q2^2 - 4*a^2*f*q1^2*q2^4 + 8*a*b*f*q1^2*q2^4 - 4*b^2*f*q1^2*q2^4 - 2*a^2*g*q1^2*q2^4 + 4*a*b*g*q1^2*q2^4 - 2*b^2*g*q1^2*q2^4 - 2*a^2*f*q2^6 + 4*a*b*f*q2^6 - 2*b^2*f*q2^6 - 4*a^3*g*q1^4 + 10*a^2*b*g*q1^4 - 8*a*b^2*g*q1^4 + 2*b^3*g*q1^4 - 2*a^3*f*q1^2*q2^2 + 4*a^2*b*f*q1^2*q2^2 - 2*a*b^2*f*q1^2*q2^2 - 2*a^2*b*g*q1^2*q2^2 + 4*a*b^2*g*q1^2*q2^2 - 2*b^3*g*q1^2*q2^2 + 2*a^3*f*q2^4 - 8*a^2*b*f*q2^4 + 10*a*b^2*f*q2^4 - 4*b^3*f*q2^4 - 2*a^4*g*q1^2 + 6*a^3*b*g*q1^2 - 6*a^2*b^2*g*q1^2 + 2*a*b^3*g*q1^2 + 2*a^3*b*f*q2^2 - 6*a^2*b^2*f*q2^2 + 6*a*b^3*f*q2^2 - 2*b^4*f*q2^2 - a*f*g*q1^2 + b*f*g*q1^2 + a*g^2*q1^2 - b*g^2*q1^2 - a*f^2*q2^2 + b*f^2*q2^2 + a*f*g*q2^2 - b*f*g*q2^2 - a^2*f*g + 2*a*b*f*g - b^2*f*g)*q1*q2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3))
    p1_3=-sqrt(-2*a*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 10*a*b*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 4*b^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 8*a*b*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*b^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*b*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^2*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 14*a^2*b*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 10*a*b^2*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a^4*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*a^3*b*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*b^2*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b^3*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - a^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*sqrt(4*a^4*b*q1^4*q2^2 - 16*a^3*b^2*q1^4*q2^2 + 24*a^2*b^3*q1^4*q2^2 - 16*a*b^4*q1^4*q2^2 + 4*b^5*q1^4*q2^2 + 4*a^5*q1^2*q2^4 - 16*a^4*b*q1^2*q2^4 + 24*a^3*b^2*q1^2*q2^4 - 16*a^2*b^3*q1^2*q2^4 + 4*a*b^4*q1^2*q2^4 + 4*a^5*b*q1^2*q2^2 - 16*a^4*b^2*q1^2*q2^2 + 24*a^3*b^3*q1^2*q2^2 - 16*a^2*b^4*q1^2*q2^2 + 4*a*b^5*q1^2*q2^2 - 2*a^2*g*q1^6 + 4*a*b*g*q1^6 - 2*b^2*g*q1^6 - 2*a^2*f*q1^4*q2^2 + 4*a*b*f*q1^4*q2^2 - 2*b^2*f*q1^4*q2^2 - 4*a^2*g*q1^4*q2^2 + 8*a*b*g*q1^4*q2^2 - 4*b^2*g*q1^4*q2^2 - 4*a^2*f*q1^2*q2^4 + 8*a*b*f*q1^2*q2^4 - 4*b^2*f*q1^2*q2^4 - 2*a^2*g*q1^2*q2^4 + 4*a*b*g*q1^2*q2^4 - 2*b^2*g*q1^2*q2^4 - 2*a^2*f*q2^6 + 4*a*b*f*q2^6 - 2*b^2*f*q2^6 - 4*a^3*g*q1^4 + 10*a^2*b*g*q1^4 - 8*a*b^2*g*q1^4 + 2*b^3*g*q1^4 - 2*a^3*f*q1^2*q2^2 + 4*a^2*b*f*q1^2*q2^2 - 2*a*b^2*f*q1^2*q2^2 - 2*a^2*b*g*q1^2*q2^2 + 4*a*b^2*g*q1^2*q2^2 - 2*b^3*g*q1^2*q2^2 + 2*a^3*f*q2^4 - 8*a^2*b*f*q2^4 + 10*a*b^2*f*q2^4 - 4*b^3*f*q2^4 - 2*a^4*g*q1^2 + 6*a^3*b*g*q1^2 - 6*a^2*b^2*g*q1^2 + 2*a*b^3*g*q1^2 + 2*a^3*b*f*q2^2 - 6*a^2*b^2*f*q2^2 + 6*a*b^3*f*q2^2 - 2*b^4*f*q2^2 - a*f*g*q1^2 + b*f*g*q1^2 + a*g^2*q1^2 - b*g^2*q1^2 - a*f^2*q2^2 + b*f^2*q2^2 + a*f*g*q2^2 - b*f*g*q2^2 - a^2*f*g + 2*a*b*f*g - b^2*f*g)*q1*q2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3))
    p1_4=sqrt(-2*a*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 10*a*b*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 4*b^2*q1^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 8*a*b*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*b^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*b*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^2*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 14*a^2*b*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 10*a*b^2*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^3*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a^4*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*a^3*b*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a^2*b^2*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b^3*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*f*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - a^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b^2*f/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*sqrt(4*a^4*b*q1^4*q2^2 - 16*a^3*b^2*q1^4*q2^2 + 24*a^2*b^3*q1^4*q2^2 - 16*a*b^4*q1^4*q2^2 + 4*b^5*q1^4*q2^2 + 4*a^5*q1^2*q2^4 - 16*a^4*b*q1^2*q2^4 + 24*a^3*b^2*q1^2*q2^4 - 16*a^2*b^3*q1^2*q2^4 + 4*a*b^4*q1^2*q2^4 + 4*a^5*b*q1^2*q2^2 - 16*a^4*b^2*q1^2*q2^2 + 24*a^3*b^3*q1^2*q2^2 - 16*a^2*b^4*q1^2*q2^2 + 4*a*b^5*q1^2*q2^2 - 2*a^2*g*q1^6 + 4*a*b*g*q1^6 - 2*b^2*g*q1^6 - 2*a^2*f*q1^4*q2^2 + 4*a*b*f*q1^4*q2^2 - 2*b^2*f*q1^4*q2^2 - 4*a^2*g*q1^4*q2^2 + 8*a*b*g*q1^4*q2^2 - 4*b^2*g*q1^4*q2^2 - 4*a^2*f*q1^2*q2^4 + 8*a*b*f*q1^2*q2^4 - 4*b^2*f*q1^2*q2^4 - 2*a^2*g*q1^2*q2^4 + 4*a*b*g*q1^2*q2^4 - 2*b^2*g*q1^2*q2^4 - 2*a^2*f*q2^6 + 4*a*b*f*q2^6 - 2*b^2*f*q2^6 - 4*a^3*g*q1^4 + 10*a^2*b*g*q1^4 - 8*a*b^2*g*q1^4 + 2*b^3*g*q1^4 - 2*a^3*f*q1^2*q2^2 + 4*a^2*b*f*q1^2*q2^2 - 2*a*b^2*f*q1^2*q2^2 - 2*a^2*b*g*q1^2*q2^2 + 4*a*b^2*g*q1^2*q2^2 - 2*b^3*g*q1^2*q2^2 + 2*a^3*f*q2^4 - 8*a^2*b*f*q2^4 + 10*a*b^2*f*q2^4 - 4*b^3*f*q2^4 - 2*a^4*g*q1^2 + 6*a^3*b*g*q1^2 - 6*a^2*b^2*g*q1^2 + 2*a*b^3*g*q1^2 + 2*a^3*b*f*q2^2 - 6*a^2*b^2*f*q2^2 + 6*a*b^3*f*q2^2 - 2*b^4*f*q2^2 - a*f*g*q1^2 + b*f*g*q1^2 + a*g^2*q1^2 - b*g^2*q1^2 - a*f^2*q2^2 + b*f^2*q2^2 + a*f*g*q2^2 - b*f*g*q2^2 - a^2*f*g + 2*a*b*f*g - b^2*f*g)*q1*q2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3))
    p1_10=(p1_1.subs([q1==q10,q2==q20]))
    print(p1_10)
    p1_20=p1_2.subs([q1==q10,q2==q20])
    print(p1_20)
    p1_30=p1_3.subs([q1==q10,q2==q20])
    print(p1_30)
    p1_40=p1_4.subs([q1==q10,q2==q20])
    print(p1_40)
    if (p1_10==(p10)):
        print("*")
        return SR(p1_1)
    if bool(p1_20==p10)==true:
        return p1_2
    if bool(p1_30==p10)==true:
        return p1_3
    if bool(p1_40==p10)==true:
        return p1_4
    else:
        return False

# %%
branch_selection_1(q10=1,q20=3,p10=-8,p20=2,a=0,b=3)
# Out:
# -8
# 8
# -100*sqrt(1/157)
# 100*sqrt(1/157)
# *
# -sqrt(-2*q1^8/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^6*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^4*q2^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 2*q1^2*q2^6/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 12*q1^6/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 6*q1^4*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^2*q2^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 304*q1^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 322*q1^2*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 4*sqrt(19*q1^6 - 399*q1^4*q2^2 - 909*q1^2*q2^4 - 464*q2^6 - 57*q1^4 + 57*q1^2*q2^2 - 2784*q2^4 - 3059*q1^2 + 70528*q2^2 + 8816)*q1*q2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 1894*q1^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 928*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 2784/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9))

# %%
branch_selection_1(q10=1,q20=-3,p10=-8,p20=2,a=0,b=3)
# Out:
# -76*sqrt(1/157)
# 76*sqrt(1/157)
# -8
# 8
# -sqrt(-2*q1^8/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^6*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^4*q2^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 2*q1^2*q2^6/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 12*q1^6/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 6*q1^4*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^2*q2^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 304*q1^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 322*q1^2*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 4*sqrt(115*q1^6 - 111*q1^4*q2^2 - 621*q1^2*q2^4 - 368*q2^6 - 345*q1^4 + 345*q1^2*q2^2 - 2208*q2^4 - 18515*q1^2 + 55936*q2^2 + 42320)*q1*q2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 1702*q1^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 736*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 2208/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9))

# %% [markdown]
# # ВЕТВЬ ДЕЙСТВИТЕЛЬНО ИДЕНТИФИЦИРОВАНА!!!

# %%
branch_selection_1(q10=1,q20=4,p10=4,p20=2,a=0,b=3)
# Out:
# -4
# 4
# -28*sqrt(1/97)
# 28*sqrt(1/97)
# sqrt(-2*q1^8/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^6*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^4*q2^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 2*q1^2*q2^6/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 12*q1^6/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 6*q1^4*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^2*q2^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 676*q1^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 694*q1^2*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 4*sqrt(868*q1^6 + 1590*q1^4*q2^2 + 522*q1^2*q2^4 - 173*q2^6 - 2604*q1^4 + 2604*q1^2*q2^2 - 1038*q2^4 - 301196*q1^2 + 58474*q2^2 + 150164)*q1*q2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 2428*q1^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 346*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 1038/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9))

# %%
branch_selection_1(q10=0,q20=4,p10=4,p20=2,a=0,b=3)
# Out:
# -4
# 4
# -4
# 4
# sqrt(-2*q1^8/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^6*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^4*q2^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 2*q1^2*q2^6/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 12*q1^6/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 6*q1^4*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^2*q2^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 610*q1^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 628*q1^2*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 4*sqrt(790*q1^6 + 1455*q1^4*q2^2 + 486*q1^2*q2^4 - 152*q2^6 - 2370*q1^4 + 2370*q1^2*q2^2 - 912*q2^4 - 248060*q1^2 + 46360*q2^2 + 120080)*q1*q2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 2188*q1^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 304*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 912/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9))

# %%
branch_selection_1(q10=1,q20=0,p10=4,p20=2,a=0,b=3)
# Out:
# -4
# 4
# -4
# 4
# sqrt(-2*q1^8/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^6*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^4*q2^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 2*q1^2*q2^6/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 12*q1^6/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 6*q1^4*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 6*q1^2*q2^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 4*q1^4/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 22*q1^2*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 4*sqrt(4*q1^6 + 6*q1^4*q2^2 - 54*q1^2*q2^4 - 29*q2^6 - 12*q1^4 + 12*q1^2*q2^2 - 174*q2^4 - 44*q1^2 + 58*q2^2 + 116)*q1*q2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) - 124*q1^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 58*q2^2/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9) + 174/(q1^4 + 2*q1^2*q2^2 + q2^4 - 6*q1^2 + 6*q2^2 + 9))

# %%
integral(p1_4.subs(a=1,b=1/3,f=0,g=0, q2=0),q1)
# Out:
# 1/3*(I*sqrt(2)*q1^2 + I*sqrt(2))*sqrt(q1^2 + 1)

# %%
integral(p1_3.subs(a=1,b=1/3,f=0,g=0, q2=0),q1)
# Out:
# -1/3*(I*sqrt(2)*q1^2 + I*sqrt(2))*sqrt(q1^2 + 1)

# %%
integral(p1_1.subs(a=1,b=1/3,f=0,g=0, q2=0),q1)
# Out:
# -1/3*(I*sqrt(2)*q1^2 + I*sqrt(2))*sqrt(q1^2 + 1)

# %%
integral(p1_2.subs(a=1,b=1/3,f=0,g=0, q2=0),q1)
# Out:
# 1/3*(I*sqrt(2)*q1^2 + I*sqrt(2))*sqrt(q1^2 + 1)

# %% [markdown]
# $$$$
#
# Зная начальные условия, можно восстановить значения
# энергии, интегралов движения в нулевой момент времени.
#
# Далее следует проверить: какую из 4-х формул выбирать. Подставить все условия, кроме р1 и посмотреть, на какой из формул будет совпадение.
#
# Взяв правильную формулу, в которую подставить параметры a, b, f, g, задаться вопросом об интегрировании в символьном виде алгебраической функции. лишнюю q2 заморозить \ менять вдоль какой-то сетки.?????
#
# Интегрирование должно вестись по области классически возможного движения.
#
# Как найти такую область?
#
# Область изменения q1.
#
# Находится из начальных условий-> параметры интегралов -> условие вещественности выбранной ветви p_1_izbr.
#
# Как написать такое условие ?
#
# Схема интегрирования.
#
# 1. явные формулы для ветвей
# 2. выбор ветвей по начальным условиям
# # 3. начинаем интегрирование. нужна область допустимости.
# 5. интегралы пытаемся найти из функций Клейна ?
# 6. новые интегралы,??

# %%
p1_1c=p1_1.subs(a==1,b==1/2)
show(p1_1c)
# Out:
# -sqrt(-8*q1^8/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) - 24*q1^6*q2^2/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) - 24*q1^4*q2^4/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) - 8*q1^2*q2^6/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) - 16*q1^6/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) - 20*q1^4*q2^2/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) - 4*q1^2*q2^4/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) - 8*f*q1^4/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) + 8*g*q1^4/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) - 8*f*q1^2*q2^2/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) + 8*g*q1^2*q2^2/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) - 10*q1^4/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) - 8*f*q1^2/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) + 4*g*q1^2/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2 + 1) + 4*f*q2^2/(4*q1^4 + 8*q1^2*q2^2 + 4*q2^4 + 4*q1^2 - 4*q2^2
# ...

# %%
integral(p1_1c,q1)

# %% [markdown]
# Теперь берем
# $$
# F(q_1,q_2,p_1)=0
# $$
# и дифференцируем по $q_2$
# $$
# F_{q_2}+ F_{p_1} u=0
# $$
# Отсюда
# $$
# u=-F_{q_2}/F_{p_1}
# $$

# %%
u=-diff(SR(Eqp1),q2)/diff(SR(Eqp1),p1)
u

# %% [markdown]
# Шаг 2. Ищем
# $$
# v= \frac{\partial p_2}{\partial q_1}
# $$
# В определении кольца переставляем $p_1$ и $p_2$ и получаем
# $$
# F_2(q_1,q_2,p_2)=0
# $$

# %%
k=PolynomialRing(QQ,[p1,p2,q2,q1,a,b,f,g], order='lex')
J=k*[F==f,G==g]
B=J.groebner_basis()

# %%
Eqp2=QQ[q1,q2,a,b,f,g][p2](B[-1])
Eqp2

# %%
pp2=solve(SR(Eqp2),p2)
pp2[0]

# %%
p2_1= -sqrt(-2*a*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q1^6*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^4*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b*q1^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*q2^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*q2^8/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a^2*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a*b*q1^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*a^2*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 8*a*b*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b^2*q1^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 4*a^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 10*a*b*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b^2*q2^6/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a^3*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 10*a^2*b*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 14*a*b^2*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*b^3*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a^3*b*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 6*a^2*b^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 6*a*b^3*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b^4*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q1^2*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - f*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + g*q2^4/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*g*q1^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - b*f*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*g*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + 2*b*g*q2^2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + a^2*g/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*a*b*g/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) + b^2*g/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3) - 2*sqrt(4*a^4*b*q1^4*q2^2 - 16*a^3*b^2*q1^4*q2^2 + 24*a^2*b^3*q1^4*q2^2 - 16*a*b^4*q1^4*q2^2 + 4*b^5*q1^4*q2^2 + 4*a^5*q1^2*q2^4 - 16*a^4*b*q1^2*q2^4 + 24*a^3*b^2*q1^2*q2^4 - 16*a^2*b^3*q1^2*q2^4 + 4*a*b^4*q1^2*q2^4 + 4*a^5*b*q1^2*q2^2 - 16*a^4*b^2*q1^2*q2^2 + 24*a^3*b^3*q1^2*q2^2 - 16*a^2*b^4*q1^2*q2^2 + 4*a*b^5*q1^2*q2^2 - 2*a^2*g*q1^6 + 4*a*b*g*q1^6 - 2*b^2*g*q1^6 - 2*a^2*f*q1^4*q2^2 + 4*a*b*f*q1^4*q2^2 - 2*b^2*f*q1^4*q2^2 - 4*a^2*g*q1^4*q2^2 + 8*a*b*g*q1^4*q2^2 - 4*b^2*g*q1^4*q2^2 - 4*a^2*f*q1^2*q2^4 + 8*a*b*f*q1^2*q2^4 - 4*b^2*f*q1^2*q2^4 - 2*a^2*g*q1^2*q2^4 + 4*a*b*g*q1^2*q2^4 - 2*b^2*g*q1^2*q2^4 - 2*a^2*f*q2^6 + 4*a*b*f*q2^6 - 2*b^2*f*q2^6 - 4*a^3*g*q1^4 + 10*a^2*b*g*q1^4 - 8*a*b^2*g*q1^4 + 2*b^3*g*q1^4 - 2*a^3*f*q1^2*q2^2 + 4*a^2*b*f*q1^2*q2^2 - 2*a*b^2*f*q1^2*q2^2 - 2*a^2*b*g*q1^2*q2^2 + 4*a*b^2*g*q1^2*q2^2 - 2*b^3*g*q1^2*q2^2 + 2*a^3*f*q2^4 - 8*a^2*b*f*q2^4 + 10*a*b^2*f*q2^4 - 4*b^3*f*q2^4 - 2*a^4*g*q1^2 + 6*a^3*b*g*q1^2 - 6*a^2*b^2*g*q1^2 + 2*a*b^3*g*q1^2 + 2*a^3*b*f*q2^2 - 6*a^2*b^2*f*q2^2 + 6*a*b^3*f*q2^2 - 2*b^4*f*q2^2 - a*f*g*q1^2 + b*f*g*q1^2 + a*g^2*q1^2 - b*g^2*q1^2 - a*f^2*q2^2 + b*f^2*q2^2 + a*f*g*q2^2 - b*f*g*q2^2 - a^2*f*g + 2*a*b*f*g - b^2*f*g)*q1*q2/(a*q1^4 - b*q1^4 + 2*a*q1^2*q2^2 - 2*b*q1^2*q2^2 + a*q2^4 - b*q2^4 + 2*a^2*q1^2 - 4*a*b*q1^2 + 2*b^2*q1^2 - 2*a^2*q2^2 + 4*a*b*q2^2 - 2*b^2*q2^2 + a^3 - 3*a^2*b + 3*a*b^2 - b^3))

# %%
(diff(p1_1,q2).subs(a==1,b==1/2,f==7).subs(q1==1).subs(q2==2).subs(g=9)).minpoly()

# %%
(diff(p2_1,q1).subs(a==1,b==1/2,f==7).subs(q1==1).subs(q2=2).subs(g=9)).minpoly()

# %%
QQbar(diff(p2_1,q1).subs(a==1,b==1/2,f==7).subs(q1==1).subs(q2=2).subs(g=9))

# %%
QQbar(diff(p1_1,q2).subs(a==1,b==1/2,f==7).subs(q1==1).subs(q2==2).subs(g=9))

# %%
v=-diff(SR(Eqp2),q1)/diff(SR(Eqp2),p2)
v

# %% [markdown]
# Шаг 3. Нам нужно проверить
# $$
# \frac{\partial p_1}{\partial q_2}=\frac{\partial p_2}{\partial q_1},
# $$
# то есть верно ли равенство
# $$
# u(q_1,q_2,p_1)=v(q_1,q_2,p_2)
# $$
# при всех $p_1,p_2,q_1,q_2$. Верно ли, что числитель разность $u-v$ принадлежит иделалу $J$, порожденному элементами $F-f, G-g$?

# %%
w=SR(u-v).numerator()
w

# %%
k=PolynomialRing(QQ,[p1,p2,q2,q1,a,b,f,g])
J=k*[F==f,G==g]

# %%
w in J

# %% [markdown]
# Да, верно. Лиувилль прав!
